# %%
import random

#initializing constants and empty variables

card_ranks_list = ["Ace", "2", "3", "4", "5", "6", "7", "8", "9", "10", "Jack", "Queen", "King"]
card_houses_list = ["Clubs", "Diamonds", "Hearts", "Spades"]
ten_list = ["Jack", "Queen", "King"]
hit_list = [True, False]
win = 0
lose = 0
draw = 0
game = 0

#========================================================================================================
#Creating a function to deal the first two cards to the player

def player_deal():
    first_card = ""
    second_card = ""
    player_cards = []
    
    if dealt_cards_list == []:
        first_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)
        player_cards.append(first_card)
        second_card = first_card

        while second_card == first_card:
            second_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)
            player_cards.append(second_card)
    else:
        while first_card in dealt_cards_list:
            first_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)
            
        player_cards.append(first_card)
        second_card = first_card
            
        while second_card == first_card:
            second_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)
            
        player_cards.append(second_card)
    
    return player_cards
#========================================================================================================
#Creating a function for the dealer to deal his cards

def dealer_deal():
    first_card = dealt_cards_list[0]
    second_card = dealt_cards_list[0]
    dealer_cards = []
    
    while first_card in dealt_cards_list:
        first_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)

    dealer_cards.append(first_card)

    while second_card in dealt_cards_list:
        second_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)

    dealer_cards.append(second_card)
    
    return dealer_cards

#========================================================================================================
#Calculating player's points:
def player_point():
    player_point = 0
    for i in range(len(player_cards_list)):
        if player_cards_list[i].split()[0] == "Ace":
            if 21 - player_point >= 11:
                player_point += 11
            else:
                player_point += 1
        elif player_cards_list[i].split()[0] in ten_list:
            player_point += 10
        else:
            player_point += int(player_cards_list[i].split()[0])
        
#     if ace == True and player_point > 21:
#         player_point -= 10
#     else:
#         player_point -= 0
    
    return player_point

#========================================================================================================
#A function to calculate the dealer's point

def dealer_point():
    dealer_point = 0
    for i in range(len(dealer_cards_list)):
        if dealer_cards_list[i].split()[0] == "Ace":
            if 21 - dealer_point >= 11:
                dealer_point += 11
            else:
                dealer_point += 1
        elif dealer_cards_list[i].split()[0] in ten_list:
            dealer_point += 10
        else:
            dealer_point += int(dealer_cards_list[i].split()[0])
        
#     if ace == True and dealer_point > 21:
#         dealer_point -= 10
#     else:
#         dealer_point -= 0
        
    return dealer_point

#========================================================================================================
#This function deals only one card. It's the hitting function for both computer and player

def hit_card():
    hit_card_list = []
    #initializing the hit_card variable
    hit_card = dealt_cards_list[0]
    
    while hit_card in dealt_cards_list:
        hit_card = random.choice(card_ranks_list) + " " + random.choice(card_houses_list)
    
    hit_card_list.append(hit_card)
    return hit_card_list

#========================================================================================================
#Calling the player_deal() function and take the values with the 'player_cards_list' list
#Adding the player's dealt cards to the 'dealt_cards_list' list

#The program's master loop
play_again = ("Y")
while play_again in ("Y", "y"):
    #initializing values
    player_cards_list = []
    dealer_cards_list = []
    dealt_cards_list = []
    player_stand = False
    dealer_stand = False
    sum_dealer_point = 0
    sum_player_point = 0
    
    print("***Welcome! Gambler!***")

    player_cards_list = player_deal()
    dealt_cards_list += player_cards_list

#========================================================================================================
#Showing two initial player cards

    print("Your cards are:")
    for i in range(len(player_cards_list)):
        print(f"{player_cards_list[i].split()[0]} of {player_cards_list[i].split()[1]}")

#========================================================================================================
#Showing player's cards and dealt cards
    
    sum_player_point = player_point()
    print(f"You now have {sum_player_point} points.")
    print(f"Dealt cards: {dealt_cards_list}")
    print("========================================================================================================")
    
#========================================================================================================
    #dealer's turn to deal
    dealer_cards_list = dealer_deal()
    dealt_cards_list += dealer_cards_list

#========================================================================================================
#Show all dealer's cards

    print("Dealer's cards are:")
    for i in range(len(dealer_cards_list)):
        print(f"{dealer_cards_list[i].split()[0]} of {dealer_cards_list[i].split()[1]}")

#========================================================================================================
#Show dealer's point and dealt cards

    sum_dealer_point = dealer_point()

    print(f"The dealer now has {sum_dealer_point} points.")
    print(f"Dealt cards: {dealt_cards_list}")
    print("========================================================================================================")

#========================================================================================================
#Determine if the dealer has to hit or not:
    
    if sum_dealer_point < 17:
        print("The deler's point is below 17, he hits for another card.")
        dealer_cards_list.append(hit_card()[0])
        dealt_cards_list.append(dealer_cards_list[-1])
        print("Dealer's cards are:")
        dealer_stand = False

        for i in range(len(dealer_cards_list)):
            print(f"{dealer_cards_list[i].split()[0]} of {dealer_cards_list[i].split()[1]}")

        sum_dealer_point = dealer_point()

        print(f"Dealer now has {sum_dealer_point} points.")
        print(f"Dealt cards: {dealt_cards_list}")

    if sum_dealer_point > 21:
        print("The dealer's point is above 21. You win!")
        print("========================================================================================================")
        win += 1
        game += 1
    elif sum_player_point == 21:
        print("You win!")
        print("========================================================================================================")
        win += 1
        game += 1
    elif sum_dealer_point == 21:
        print("You lose!")
        print("========================================================================================================")
        lose += 1
        game += 1
    elif sum_dealer_point == 21 and sum_player_point == 21:
        print("It's a draw!")
        print("========================================================================================================")
        draw +=1
        game +=1
    else:    
        while player_stand != True or dealer_stand != True:
            #Ask the player if he/she wants to hit?
            hit = ("") #For the player to hit
            while hit not in ("Y","y","N","n"):
                hit = input("Hit? Y/N: ")

            if hit in ("Y", "y"):
                print("Player hits!")
                player_cards_list.append(hit_card()[0])
                dealt_cards_list.append(player_cards_list[-1])
                print("Player cards are:")
                player_stand = False

                for i in range(len(player_cards_list)):
                    print(f"{player_cards_list[i].split()[0]} of {player_cards_list[i].split()[1]}")

                sum_player_point = player_point()

                print(f"Player now has {sum_player_point} points.")
                print(f"Dealt cards: {dealt_cards_list}")
                
                if sum_player_point > 21:
                    print("You lose!")
                    print(f"Dealt cards: {dealt_cards_list}")
                    lose += 1
                    game += 1
                    break
                    
                elif sum_player_point == 21:
                    print("You win!")
                    print(f"Dealt cards: {dealt_cards_list}")
                    win += 1
                    game += 1
                    break
#                 else:
#                     if 21 - sum_player_point < 21 - sum_dealer_point:
#                         print("You win!")
#                         win += 1
#                         game += 1
#                         break
#                     elif 21 - sum_player_point > 21 - sum_dealer_point:
#                         print("You lose!")
#                         lose += 1
#                         game += 1
#                         break
#                     else:
#                         print("It's a draw!")
#                         draw += 1
#                         game += 1
#                         break
                
                print("========================================================================================================")

            else:
                print("Player stands!")
                sum_player_point += 0
                player_stand = True

            #Determine if the deler wants to hit===========================================================
            if sum_dealer_point <= 17:
                hit_or_not = random.choices(hit_list,weights=(99,1),k=1)
            elif sum_dealer_point == 18:
                hit_or_not = random.choices(hit_list,weights=(60,40),k=1)
            elif sum_dealer_point == 19:
                hit_or_not = random.choices(hit_list,weights=(5,95),k=1)
            elif sum_dealer_point == 20:
                hit_or_not = random.choices(hit_list,weights=(1,99),k=1)
            elif sum_dealer_point ==21:
                hit_or_not = random.choices(hit_list,wiehgts=(0,100),k=1)
            #==================================================================================================

            #for the dealer:
            if hit_or_not == [True]:
                dealer_stand = False
                print("Dealer hits!")
                dealer_cards_list.append(hit_card()[0])
                dealt_cards_list.append(dealer_cards_list[-1])       
               
                print("Dealer's cards are:")

                for i in range(len(dealer_cards_list)):
                    print(f"{dealer_cards_list[i].split()[0]} of {dealer_cards_list[i].split()[1]}")
                    
                sum_dealer_point = dealer_point()
                    
                print(f"Dealer now has {sum_dealer_point} points.")
                print(f"Dealt cards: {dealt_cards_list}")
                
                if sum_dealer_point > 21:
                    print("You win!")
                    print(f"Dealt cards: {dealt_cards_list}")
                    win += 1
                    game += 1
                    break
                    
                elif sum_dealer_point == 21:
                    print("You lose!")
                    print(f"Dealt cards: {dealt_cards_list}")
                    lose += 1
                    game += 1
                    break
                
#                 else:
#                     if 21 - sum_player_point < 21 - sum_dealer_point:
#                         print("You win!")
#                         win += 1
#                         game += 1
#                         break
#                     elif 21 - sum_player_point > 21 - sum_dealer_point:
#                         print("You lose!")
#                         lose += 1
#                         game += 1
#                         break
#                     else:
#                         print("It's a draw!")
#                         draw += 1
#                         game += 1
#                         break
                
                print("========================================================================================================")
            else:
                print("Dealer stands!")
                sum_dealer_point += 0
                dealer_stand = True
            
        if dealer_stand == True and player_stand == True:

            if 21 - sum_player_point < 21 - sum_dealer_point:
                print("You win!")
                print(f"Dealt cards: {dealt_cards_list}")
                win += 1
                game += 1
            elif 21 - sum_player_point > 21 - sum_dealer_point:
                print("You lose!")
                print(f"Dealt cards: {dealt_cards_list}")
                lose += 1
                game += 1
            else:
                print("It's a draw!")
                print(f"Dealt cards: {dealt_cards_list}")
                draw += 1
                game += 1

   
    print("========================================================================================================")
    
    
    play_again = ("")
    while play_again not in ("Y", "y", "N","n"):
        play_again = input("Play again? Y/N:")   

if game == 1:
    print(f"You have played {game} game. You win {win} time, lose {lose} time, and draw {draw} time.")
else:
    if win == 1 and lose == 1 and draw == 1:
        print(f"You have played {game} game. You win {win} time, lose {lose} time, and draw {draw} time.")
    else:
        if win > 1 and lose == 1 and draw == 1:
            print(f"You have played {game} game. You win {win} times, lose {lose} time, and draw {draw} time.")
        elif win == 1 and lose > 1 and draw == 1:
            print(f"You have played {game} game. You win {win} time, lose {lose} times, and draw {draw} time.")
        elif lose == 1 and draw == 1 and win > 1:
            print(f"You have played {game} game. You win {win} time, lose {lose} time, and draw {draw} times.")
        elif win > 1 and lose > 1 and draw == 1:
            print(f"You have played {game} game. You win {win} times, lose {lose} times, and draw {draw} time.")
        elif win > 1 and lose == 1 and draw > 1:
            print(f"You have played {game} game. You win {win} times, lose {lose} time, and draw {draw} times.")
        elif win == 1 and lose > 1 and draw > 1:
            print(f"You have played {game} game. You win {win} time, lose {lose} times, and draw {draw} times.")
        elif win > 1 and lose > 1 and draw > 1:
            print(f"You have played {game} game. You win {win} times, lose {lose} times, and draw {draw} times.")
        elif win > 1 and lose <= 1 and draw <= 1:
            print(f"You have played {game} game. You win {win} times, lose {lose} time, and draw {draw} time.")
        elif win <= 1 and lose > 1 and draw <= 1:
            print(f"You have played {game} game. You win {win} time, lose {lose} times, and draw {draw} time.")
        elif win <= 1 and lose <= 1 and draw > 1:
            print(f"You have played {game} game. You win {win} time, lose {lose} time, and draw {draw} times.")
